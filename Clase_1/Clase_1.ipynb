# %% [markdown]
# # TRABAJANDO CON PANDAS

# %% [markdown]
# ### Encontrar variables con alta correlación

# %%
# Importar la libreria pandas
import pandas as pd

# %%
#Redireccionar el csv en una bd con nombre aire
aire = pd.read_csv("air.csv")

# %%
#Mostrar los primeros elementos de la data aire
aire.head()

#Se aprecia:
# El formato fecha (18.00.00) esta separado por puntos
# La fecha esta en DD/MM/YY
# No tengo missing (datos faltantes)
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/3/2004  18.00.00     2.6         1360     150.0      11.9
# 1  10/3/2004  19.00.00     2.0         1292     112.0       9.4
# 2  10/3/2004  20.00.00     2.2         1402      88.0       9.0
# 3  10/3/2004  21.00.00     2.2         1376      80.0       9.2
# 4  10/3/2004  22.00.00     1.6         1272      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692       1268.0
# 1            955      103          1174       92          1559        972.0
# 2            939      131          1140      114          1555       1074.0
# 3            948      172          1092      122          1584       1203.0
# 4            836      131          1205      116          1490       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
#Mostrar los últimos elementos de la data aire
aire.tail()
# Out:
#           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  4/4/2005  10.00.00     3.1         1314    -200.0      13.5
# 9353  4/4/2005  11.00.00     2.4         1163    -200.0      11.4
# 9354  4/4/2005  12.00.00     2.4         1142    -200.0      12.4
# 9355  4/4/2005  13.00.00     2.1         1003    -200.0       9.5
# 9356  4/4/2005  14.00.00     2.2         1071    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# ...

# %%
#Mostrar las estadísticas básicas de la data aire
aire.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.033536  1048.816074  -159.066485     2.004628     894.432724
# std      79.096080   330.062067   139.800836    43.568942     342.491834
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max    1428.000000  2040.000000  1189.000000  1321.000000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.696484    794.910655    58.360372   1391.462755   974.900780
# std     257.434899    322.147362   128.153143    467.198972   456.996348
# ...

# %%
#Mostrando la columna Time
aire['Time']
# Out:
# 0       18.00.00
# 1       19.00.00
# 2       20.00.00
# 3       21.00.00
# 4       22.00.00
#           ...
# 9352    10.00.00
# 9353    11.00.00
# 9354    12.00.00
# 9355    13.00.00
# 9356    14.00.00
# Name: Time, Length: 9357, dtype: object

# %%
# Deseo reemplazar "." por ":"
aire['Time'].replace('.',':')

#Para este tipo de datos el replace no cumple su función
# Out:
# 0       18.00.00
# 1       19.00.00
# 2       20.00.00
# 3       21.00.00
# 4       22.00.00
#           ...
# 9352    10.00.00
# 9353    11.00.00
# 9354    12.00.00
# 9355    13.00.00
# 9356    14.00.00
# Name: Time, Length: 9357, dtype: object

# %%
#El replace con el string si cambia
"19.00.00".replace('.',':')
# Out:
# '19:00:00'

# %%
aire['Time']= aire['Time'].replace(to_replace='.', value=':')
aire['Time']
# Out:
# 0       18.00.00
# 1       19.00.00
# 2       20.00.00
# 3       21.00.00
# 4       22.00.00
#           ...
# 9352    10.00.00
# 9353    11.00.00
# 9354    12.00.00
# 9355    13.00.00
# 9356    14.00.00
# Name: Time, Length: 9357, dtype: object

# %%
aire['Time'].head()
# Out:
# 0    18.00.00
# 1    19.00.00
# 2    20.00.00
# 3    21.00.00
# 4    22.00.00
# Name: Time, dtype: object

# %%
#Usando apply (aplica a la serie una función lambda, la cual solo existe mientras se corra el apply)
aire['Time'].apply(lambda x: x.replace('.',':'))[:10]
# Out:
# 0    18:00:00
# 1    19:00:00
# 2    20:00:00
# 3    21:00:00
# 4    22:00:00
# 5    23:00:00
# 6    00:00:00
# 7    01:00:00
# 8    02:00:00
# 9    03:00:00
# Name: Time, dtype: object

# %%
#Los cambios se están guardando en timeNuevo
timeNuevo = aire['Time'].apply(lambda x: x.replace('.',':'))
timeNuevo
# Out:
# 0       18:00:00
# 1       19:00:00
# 2       20:00:00
# 3       21:00:00
# 4       22:00:00
#           ...
# 9352    10:00:00
# 9353    11:00:00
# 9354    12:00:00
# 9355    13:00:00
# 9356    14:00:00
# Name: Time, Length: 9357, dtype: object

# %%
# Aqui si reemplaza por que le indico que estoy trabajando con regex
aire['Time'].replace("\.",":", regex= True)[:10]
# Out:
# 0    18:00:00
# 1    19:00:00
# 2    20:00:00
# 3    21:00:00
# 4    22:00:00
# 5    23:00:00
# 6    00:00:00
# 7    01:00:00
# 8    02:00:00
# 9    03:00:00
# Name: Time, dtype: object

# %%
aire['Time'].replace("19.00.00", ":")
# Out:
# 0       18.00.00
# 1              :
# 2       20.00.00
# 3       21.00.00
# 4       22.00.00
#           ...
# 9352    10.00.00
# 9353    11.00.00
# 9354    12.00.00
# 9355    13.00.00
# 9356    14.00.00
# Name: Time, Length: 9357, dtype: object

# %%
#Asignando el valor correcto a la columna Time
aire['Time'] = aire['Time'].apply(lambda x: x.replace('.',':'))
aire['Time'].head()
# Out:
# 0    18:00:00
# 1    19:00:00
# 2    20:00:00
# 3    21:00:00
# 4    22:00:00
# Name: Time, dtype: object

# %%
aire.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/3/2004  18:00:00     2.6         1360     150.0      11.9
# 1  10/3/2004  19:00:00     2.0         1292     112.0       9.4
# 2  10/3/2004  20:00:00     2.2         1402      88.0       9.0
# 3  10/3/2004  21:00:00     2.2         1376      80.0       9.2
# 4  10/3/2004  22:00:00     1.6         1272      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692       1268.0
# 1            955      103          1174       92          1559        972.0
# 2            939      131          1140      114          1555       1074.0
# 3            948      172          1092      122          1584       1203.0
# 4            836      131          1205      116          1490       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
#Creación de diccionario
{'llave':'valor'}
dicc = {'llave':'valor','llave2':'valor2'}

# %%
dicc['llave']
# Out:
# 'valor'

# %%
dicc['llave2']
# Out:
# 'valor2'

# %%
dicc['llave3']='valor3'
dicc['llave3']
# Out:
# 'valor3'

# %%
dicc
# Out:
# {'llave': 'valor', 'llave2': 'valor2', 'llave3': 'valor3'}

# %%
#Cambiando el nombre a las columnas por diccionario
aire.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %%
#Creando el diccionario "nombre_columnas"
nombre_columnas = {
    "Date": "Fecha",
    "Time": "Hora",
    "CO(GT)": "CO",
    "PT08.S1(CO)": "oxEst",
    "NMHC(GT)": "NMHC",
    "C6H6(GT)": "Benz",
    "PT08.S2(NMHC)": "Titania",
    "NOx(GT)": "NOx",
    "PT08.S3(NOx)": "oxTung",
    "NO2(GT)": "NO2",
    "PT08.S4(NO2)": "oxTung_2",
    "PT08.S5(O3)": "oxInd",
    "T": "Temp",
    "RH": "humRel",
    "AH": "humAbs",
}

# %%
#Con rename cambiamos colums por el diccionario
#Con inplace ya no hay la necesidad de redirijir todo el cambio a la data
aire.rename(columns = nombre_columnas, inplace = True)

# %%
aire.head()
# Out:
#        Fecha      Hora   CO  oxEst   NMHC  Benz  Titania  NOx  oxTung  NO2  \
# 0  10/3/2004  18:00:00  2.6   1360  150.0  11.9     1046  166    1056  113
# 1  10/3/2004  19:00:00  2.0   1292  112.0   9.4      955  103    1174   92
# 2  10/3/2004  20:00:00  2.2   1402   88.0   9.0      939  131    1140  114
# 3  10/3/2004  21:00:00  2.2   1376   80.0   9.2      948  172    1092  122
# 4  10/3/2004  22:00:00  1.6   1272   51.0   6.5      836  131    1205  116
#
#    oxTung_2   oxInd  Temp  humRel  humAbs
# 0      1692  1268.0  13.6    48.9  0.7578
# 1      1559   972.0  13.3    47.7  0.7255
# 2      1555  1074.0  11.9    54.0  0.7502
# 3      1584  1203.0  11.0    60.0  0.7867
# 4      1490  1110.0  11.2    59.6  0.7888

# %%
#Se desea ver el comportamiento en el timpo del set de datos
#Hora y fecha deben de estar en formatos ideal
#Unique me muestra todas las horas unicas
#Sort ordena 
aire['Hora'].sort_values().unique()
# Out:
# array(['00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
#        '05:00:00', '06:00:00', '07:00:00', '08:00:00', '09:00:00',
#        '09:00:00:-200', '10:00:00', '11:00:00', '12:00:00', '13:00:00',
#        '14:00:00', '15:00:00', '16:00:00', '17:00:00', '18:00:00',
#        '19:00:00', '20:00:00', '21:00:00', '22:00:00', '23:00:00',
#        '4:00:00'], dtype=object)

# %%
#Son 26 horas
len(aire['Hora'].unique())
# Out:
# 26

# %%
aire['Hora']
# Out:
# 0       18:00:00
# 1       19:00:00
# 2       20:00:00
# 3       21:00:00
# 4       22:00:00
#           ...
# 9352    10:00:00
# 9353    11:00:00
# 9354    12:00:00
# 9355    13:00:00
# 9356    14:00:00
# Name: Hora, Length: 9357, dtype: object

# %%
#Muestrame las posiciones donde mi Hora es igual a '19:00:00'
#1° lo guardo en una máscara
mask = (aire['Hora'] == '04:00:00')

# %%
#2° Le pido que me muestre las filas donde está ese valor '19:00:00'
aire[mask]
# Out:
#            Fecha      Hora     CO  oxEst   NMHC  Benz  Titania  NOx  oxTung  \
# 10     11/3/2004  04:00:00 -200.0   1011   14.0   1.3      527   21    1818
# 34     12/3/2004  04:00:00 -200.0    831   10.0   1.1      506   21    1893
# 58    13/03/2004  04:00:00 -200.0   1147   56.0   6.2      821  109    1132
# 82    14/03/2004  04:00:00 -200.0   1130   56.0   5.2      773   70    1130
# 106   15/03/2004  04:00:00 -200.0   1078   44.0   4.0      711   66    1150
# ...          ...       ...    ...    ...    ...   ...      ...  ...     ...
# 9250  31/03/2005  04:00:00    0.5    884 -200.0   1.6      556   73     965
# 9274    1/4/2005  04:00:00 -200.0    818 -200.0   0.8      473   47    1257
# 9298    2/4/2005  04:00:00    0.4    815 -200.0   0.9      488   63    1223
# 9322    3/4/2005  04:00:00    0.5    850 -200.0   2.0      583   83     955
# 9346    4/4/2005  04:00:00 -200.0    864 -200.0   0.8      478   52    1116
#
#       NO2  oxTung_2   oxInd  Temp  humRel  humAbs
# ...

# %%
#iloc = referencaindo por índices
#iloc es la ubicación numerica de la fila x columna
aire.iloc[10,1]
# Out:
# '04:00:00'

# %%
#iloc es la ubicación numerica de la fila x columna
aire.iloc[9,1]
# Out:
# '03:00:00'

# %%
aire.iloc[1,3]
# Out:
# 1292

# %%
aire.loc[1,'oxEst']
# Out:
# 1292

# %%
#Cambiando una hora defectuosa
aire['Hora'].replace('4:00:00','04:00:00',inplace=True)
aire['Hora'].replace('09:00:00:-200','09:00:00',inplace=True)

# %%
aire['Hora'].sort_values().unique()
# Out:
# array(['00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
#        '05:00:00', '06:00:00', '07:00:00', '08:00:00', '09:00:00',
#        '10:00:00', '11:00:00', '12:00:00', '13:00:00', '14:00:00',
#        '15:00:00', '16:00:00', '17:00:00', '18:00:00', '19:00:00',
#        '20:00:00', '21:00:00', '22:00:00', '23:00:00'], dtype=object)

# %%
#Corroboramos la longitud
len(aire['Hora'].unique())
# Out:
# 24

# %%
#Voy a generar un string de fecha-hora para convertir a una columna datetime
aire['Fecha']+' '+aire['Hora']
# Out:
# 0       10/3/2004 18:00:00
# 1       10/3/2004 19:00:00
# 2       10/3/2004 20:00:00
# 3       10/3/2004 21:00:00
# 4       10/3/2004 22:00:00
#                ...
# 9352     4/4/2005 10:00:00
# 9353     4/4/2005 11:00:00
# 9354     4/4/2005 12:00:00
# 9355     4/4/2005 13:00:00
# 9356     4/4/2005 14:00:00
# Length: 9357, dtype: object

# %%
#obteniendo el primer valor
stringVal = aire['Fecha']+' '+aire['Hora']
type(stringVal.values[0])

#El string lo paso a un formato de fecha
# Out:
# str

# %%
aire['dt']= pd.to_datetime(aire['Fecha']+' '+aire['Hora'], format="%d/%m/%Y %H:%M:%S")
aire['dt']
# Out:
# dt
# 2004-03-10 18:00:00   2004-03-10 18:00:00
# 2004-03-10 19:00:00   2004-03-10 19:00:00
# 2004-03-10 20:00:00   2004-03-10 20:00:00
# 2004-03-10 21:00:00   2004-03-10 21:00:00
# 2004-03-10 22:00:00   2004-03-10 22:00:00
#                               ...
# 2005-04-04 10:00:00   2005-04-04 10:00:00
# 2005-04-04 11:00:00   2005-04-04 11:00:00
# 2005-04-04 12:00:00   2005-04-04 12:00:00
# 2005-04-04 13:00:00   2005-04-04 13:00:00
# 2005-04-04 14:00:00   2005-04-04 14:00:00
# Name: dt, Length: 9357, dtype: datetime64[ns]

# %%
type(aire['dt'].values[0])
# Out:
# numpy.datetime64

# %%
aire['dt'].apply(lambda x: x.hour)
# Out:
# dt
# 2004-03-10 18:00:00    18
# 2004-03-10 19:00:00    19
# 2004-03-10 20:00:00    20
# 2004-03-10 21:00:00    21
# 2004-03-10 22:00:00    22
#                        ..
# 2005-04-04 10:00:00    10
# 2005-04-04 11:00:00    11
# 2005-04-04 12:00:00    12
# 2005-04-04 13:00:00    13
# 2005-04-04 14:00:00    14
# Name: dt, Length: 9357, dtype: int64

# %%
aire['dt'].apply(lambda x: x.date())
# Out:
# dt
# 2004-03-10 18:00:00    2004-03-10
# 2004-03-10 19:00:00    2004-03-10
# 2004-03-10 20:00:00    2004-03-10
# 2004-03-10 21:00:00    2004-03-10
# 2004-03-10 22:00:00    2004-03-10
#                           ...
# 2005-04-04 10:00:00    2005-04-04
# 2005-04-04 11:00:00    2005-04-04
# 2005-04-04 12:00:00    2005-04-04
# 2005-04-04 13:00:00    2005-04-04
# 2005-04-04 14:00:00    2005-04-04
# Name: dt, Length: 9357, dtype: object

# %%
aire.set_index('dt')
# Out:
#                          Fecha      Hora   CO  oxEst   NMHC  Benz  Titania  \
# dt
# 2004-03-10 18:00:00  10/3/2004  18:00:00  2.6   1360  150.0  11.9     1046
# 2004-03-10 19:00:00  10/3/2004  19:00:00  2.0   1292  112.0   9.4      955
# 2004-03-10 20:00:00  10/3/2004  20:00:00  2.2   1402   88.0   9.0      939
# 2004-03-10 21:00:00  10/3/2004  21:00:00  2.2   1376   80.0   9.2      948
# 2004-03-10 22:00:00  10/3/2004  22:00:00  1.6   1272   51.0   6.5      836
# ...                        ...       ...  ...    ...    ...   ...      ...
# 2005-04-04 10:00:00   4/4/2005  10:00:00  3.1   1314 -200.0  13.5     1101
# 2005-04-04 11:00:00   4/4/2005  11:00:00  2.4   1163 -200.0  11.4     1027
# 2005-04-04 12:00:00   4/4/2005  12:00:00  2.4   1142 -200.0  12.4     1063
# 2005-04-04 13:00:00   4/4/2005  13:00:00  2.1   1003 -200.0   9.5      961
# 2005-04-04 14:00:00   4/4/2005  14:00:00  2.2   1071 -200.0  11.9     1047
#
# ...

# %%
#Correlación entre las variables que sea numérica
aire.corr()
# Out:
#                 CO     oxEst      NMHC      Benz   Titania       NOx  \
# CO        1.000000  0.033411  0.128484  0.030655  0.023333  0.519431
# oxEst     0.033411  1.000000  0.169390  0.796991  0.933161  0.277384
# NMHC      0.128484  0.169390  1.000000  0.039624  0.109643 -0.004271
# Benz      0.030655  0.796991  0.039624  1.000000  0.718144  0.003670
# Titania   0.023333  0.933161  0.109643  0.718144  1.000000  0.330810
# NOx       0.519431  0.277384 -0.004271  0.003670  0.330810  1.000000
# oxTung   -0.094579  0.088262  0.048344  0.476272 -0.072439 -0.436475
# NO2       0.678760  0.147283  0.104106  0.033202  0.170419  0.811187
# oxTung_2 -0.071228  0.844281  0.162764  0.737326  0.874119  0.035750
# oxInd     0.075021  0.892374  0.100920  0.602201  0.909895  0.461718
# Temp     -0.065466  0.753804  0.000148  0.926062  0.668272 -0.138241
# humRel   -0.048748  0.745100  0.008191  0.876136  0.585727 -0.053071
# humAbs   -0.045856  0.764933  0.012507  0.984558  0.646600 -0.095826
#
# ...

# %%
aire.corr().values
# Out:
# array([[ 1.00000000e+00,  3.34112263e-02,  1.28483612e-01,
#          3.06551189e-02,  2.33328697e-02,  5.19431410e-01,
#         -9.45785358e-02,  6.78760320e-01, -7.12279086e-02,
#          7.50206514e-02, -6.54663566e-02, -4.87476002e-02,
#         -4.58563610e-02],
#        [ 3.34112263e-02,  1.00000000e+00,  1.69390161e-01,
#          7.96991215e-01,  9.33161169e-01,  2.77384397e-01,
#          8.82621552e-02,  1.47282964e-01,  8.44281005e-01,
#          8.92373624e-01,  7.53803757e-01,  7.45099765e-01,
#          7.64933272e-01],
#        [ 1.28483612e-01,  1.69390161e-01,  1.00000000e+00,
#          3.96241239e-02,  1.09642527e-01, -4.27104217e-03,
#          4.83441287e-02,  1.04105871e-01,  1.62763713e-01,
#          1.00919958e-01,  1.48398660e-04,  8.19139136e-03,
#          1.25066698e-02],
#        [ 3.06551189e-02,  7.96991215e-01,  3.96241239e-02,
#          1.00000000e+00,  7.18143586e-01,  3.66965341e-03,
#          4.76271950e-01,  3.32019347e-02,  7.37325567e-01,
# ...

# %%
aire.set_index('dt', inplace=True)

# %%
aire.loc['2004-06-01':'2004-07-01','CO']
# Out:
# dt
# 2004-06-01 00:00:00      0.3
# 2004-06-01 01:00:00   -200.0
# 2004-06-01 02:00:00   -200.0
# 2004-06-01 03:00:00   -200.0
# 2004-06-01 04:00:00   -200.0
#                        ...
# 2004-07-01 19:00:00      4.4
# 2004-07-01 20:00:00      3.4
# 2004-07-01 21:00:00      1.9
# 2004-07-01 22:00:00      2.1
# 2004-07-01 23:00:00      2.5
# Name: CO, Length: 744, dtype: float64

# %%
jun2004 = aire.loc['2004-06-01':'2004-06-30 23:59:59']

# %%
#Creamos el setvde datos de Junio del 2004
jun2004.head()
# Out:
#                         Fecha      Hora     CO  oxEst   NMHC  Benz  Titania  \
# dt
# 2004-06-01 00:00:00  1/6/2004  00:00:00    0.3    922 -200.0   4.7      750
# 2004-06-01 01:00:00  1/6/2004  01:00:00 -200.0    830 -200.0   2.9      644
# 2004-06-01 02:00:00  1/6/2004  02:00:00 -200.0    805 -200.0   2.0      583
# 2004-06-01 03:00:00  1/6/2004  03:00:00 -200.0    760 -200.0   1.1      505
# 2004-06-01 04:00:00  1/6/2004  04:00:00 -200.0    783 -200.0   1.3      529
#
#                      NOx  oxTung  NO2  oxTung_2  oxInd  Temp  humRel  humAbs
# dt
# 2004-06-01 00:00:00   46    1085   45      1585  685.0  18.6    75.7  1.6074
# 2004-06-01 01:00:00   17    1235   23      1487  524.0  19.6    68.4  1.5443
# 2004-06-01 02:00:00   18    1339   26      1494  527.0  18.0    76.4  1.5608
# 2004-06-01 03:00:00 -200    1527 -200      1413  452.0  17.3    77.2  1.5104
# 2004-06-01 04:00:00   16    1437   24      1435  466.0  16.5    82.3  1.5318

# %%
#Exportando Junio del 2004
jun2004.to_csv('aire_junio_2004.csv')

# %%
#Eliminando columnas Fecha y Hora, luego solo guardamos ese cambio en la exportación
jun2004.drop(columns=['Fecha','Hora']).to_csv('aire_junio_2004_1.csv')

# %%
#si deseo borrar definitivamente
jun2004.drop(columns=['Fecha','Hora'], inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
jun2004
# Out:
#                         CO  oxEst   NMHC  Benz  Titania  NOx  oxTung  NO2  \
# dt
# 2004-06-01 00:00:00    0.3    922 -200.0   4.7      750   46    1085   45
# 2004-06-01 01:00:00 -200.0    830 -200.0   2.9      644   17    1235   23
# 2004-06-01 02:00:00 -200.0    805 -200.0   2.0      583   18    1339   26
# 2004-06-01 03:00:00 -200.0    760 -200.0   1.1      505 -200    1527 -200
# 2004-06-01 04:00:00 -200.0    783 -200.0   1.3      529   16    1437   24
# ...                    ...    ...    ...   ...      ...  ...     ...  ...
# 2004-06-30 19:00:00    4.9   1352 -200.0  23.3     1385  280     563  197
# 2004-06-30 20:00:00    3.5   1217 -200.0  17.6     1227  224     641  158
# 2004-06-30 21:00:00    2.5   1149 -200.0  14.5     1132  137     688  124
# 2004-06-30 22:00:00    2.5   1156 -200.0  14.4     1129  118     688  110
# 2004-06-30 23:00:00    2.6   1180 -200.0  14.2     1122  128     678  112
#
#                      oxTung_2   oxInd  Temp  humRel  humAbs
# dt
# ...

# %%
corrDf = aire.corr()
corrDf
# Out:
#                 CO     oxEst      NMHC      Benz   Titania       NOx  \
# CO        1.000000  0.033411  0.128484  0.030655  0.023333  0.519431
# oxEst     0.033411  1.000000  0.169390  0.796991  0.933161  0.277384
# NMHC      0.128484  0.169390  1.000000  0.039624  0.109643 -0.004271
# Benz      0.030655  0.796991  0.039624  1.000000  0.718144  0.003670
# Titania   0.023333  0.933161  0.109643  0.718144  1.000000  0.330810
# NOx       0.519431  0.277384 -0.004271  0.003670  0.330810  1.000000
# oxTung   -0.094579  0.088262  0.048344  0.476272 -0.072439 -0.436475
# NO2       0.678760  0.147283  0.104106  0.033202  0.170419  0.811187
# oxTung_2 -0.071228  0.844281  0.162764  0.737326  0.874119  0.035750
# oxInd     0.075021  0.892374  0.100920  0.602201  0.909895  0.461718
# Temp     -0.065466  0.753804  0.000148  0.926062  0.668272 -0.138241
# humRel   -0.048748  0.745100  0.008191  0.876136  0.585727 -0.053071
# humAbs   -0.045856  0.764933  0.012507  0.984558  0.646600 -0.095826
#
# ...

# %%
#Máscara que va pasar esa condición
corrDf > 0.8
# Out:
#              CO  oxEst   NMHC   Benz  Titania    NOx  oxTung    NO2  oxTung_2  \
# CO         True  False  False  False    False  False   False  False     False
# oxEst     False   True  False  False     True  False   False  False      True
# NMHC      False  False   True  False    False  False   False  False     False
# Benz      False  False  False   True    False  False   False  False     False
# Titania   False   True  False  False     True  False   False  False      True
# NOx       False  False  False  False    False   True   False   True     False
# oxTung    False  False  False  False    False  False    True  False     False
# NO2       False  False  False  False    False   True   False   True     False
# oxTung_2  False   True  False  False     True  False   False  False      True
# oxInd     False   True  False  False     True  False   False  False     False
# Temp      False  False  False   True    False  False   False  False     False
# ...

# %%
corrDf[corrDf > 0.8]
# Out:
#            CO     oxEst  NMHC      Benz   Titania       NOx  oxTung       NO2  \
# CO        1.0       NaN   NaN       NaN       NaN       NaN     NaN       NaN
# oxEst     NaN  1.000000   NaN       NaN  0.933161       NaN     NaN       NaN
# NMHC      NaN       NaN   1.0       NaN       NaN       NaN     NaN       NaN
# Benz      NaN       NaN   NaN  1.000000       NaN       NaN     NaN       NaN
# Titania   NaN  0.933161   NaN       NaN  1.000000       NaN     NaN       NaN
# NOx       NaN       NaN   NaN       NaN       NaN  1.000000     NaN  0.811187
# oxTung    NaN       NaN   NaN       NaN       NaN       NaN     1.0       NaN
# NO2       NaN       NaN   NaN       NaN       NaN  0.811187     NaN  1.000000
# oxTung_2  NaN  0.844281   NaN       NaN  0.874119       NaN     NaN       NaN
# oxInd     NaN  0.892374   NaN       NaN  0.909895       NaN     NaN       NaN
# Temp      NaN       NaN   NaN  0.926062       NaN       NaN     NaN       NaN
# ...

# %%
#Reemplazando los valores en blanco por "0"
corrDf[corrDf > 0.8].fillna(0)
# Out:
#            CO     oxEst  NMHC      Benz   Titania       NOx  oxTung       NO2  \
# CO        1.0  0.000000   0.0  0.000000  0.000000  0.000000     0.0  0.000000
# oxEst     0.0  1.000000   0.0  0.000000  0.933161  0.000000     0.0  0.000000
# NMHC      0.0  0.000000   1.0  0.000000  0.000000  0.000000     0.0  0.000000
# Benz      0.0  0.000000   0.0  1.000000  0.000000  0.000000     0.0  0.000000
# Titania   0.0  0.933161   0.0  0.000000  1.000000  0.000000     0.0  0.000000
# NOx       0.0  0.000000   0.0  0.000000  0.000000  1.000000     0.0  0.811187
# oxTung    0.0  0.000000   0.0  0.000000  0.000000  0.000000     1.0  0.000000
# NO2       0.0  0.000000   0.0  0.000000  0.000000  0.811187     0.0  1.000000
# oxTung_2  0.0  0.844281   0.0  0.000000  0.874119  0.000000     0.0  0.000000
# oxInd     0.0  0.892374   0.0  0.000000  0.909895  0.000000     0.0  0.000000
# Temp      0.0  0.000000   0.0  0.926062  0.000000  0.000000     0.0  0.000000
# ...

# %%
#Se hará correlación de dos variables
aire[['oxInd','oxEst']].head()
# Out:
#                       oxInd  oxEst
# dt
# 2004-03-10 18:00:00  1268.0   1360
# 2004-03-10 19:00:00   972.0   1292
# 2004-03-10 20:00:00  1074.0   1402
# 2004-03-10 21:00:00  1203.0   1376
# 2004-03-10 22:00:00  1110.0   1272

# %%
NewDf = aire[['oxInd','oxEst']]
NewDf.to_csv('altacorrelacion.csv')

# %%
NewDf.corr()
# Out:
#           oxInd     oxEst
# oxInd  1.000000  0.892374
# oxEst  0.892374  1.000000

# %%
aire.head()
# Out:
#                          Fecha      Hora   CO  oxEst   NMHC  Benz  Titania  \
# dt
# 2004-03-10 18:00:00  10/3/2004  18:00:00  2.6   1360  150.0  11.9     1046
# 2004-03-10 19:00:00  10/3/2004  19:00:00  2.0   1292  112.0   9.4      955
# 2004-03-10 20:00:00  10/3/2004  20:00:00  2.2   1402   88.0   9.0      939
# 2004-03-10 21:00:00  10/3/2004  21:00:00  2.2   1376   80.0   9.2      948
# 2004-03-10 22:00:00  10/3/2004  22:00:00  1.6   1272   51.0   6.5      836
#
#                      NOx  oxTung  NO2  oxTung_2   oxInd  Temp  humRel  humAbs
# dt
# 2004-03-10 18:00:00  166    1056  113      1692  1268.0  13.6    48.9  0.7578
# 2004-03-10 19:00:00  103    1174   92      1559   972.0  13.3    47.7  0.7255
# 2004-03-10 20:00:00  131    1140  114      1555  1074.0  11.9    54.0  0.7502
# 2004-03-10 21:00:00  172    1092  122      1584  1203.0  11.0    60.0  0.7867
# 2004-03-10 22:00:00  131    1205  116      1490  1110.0  11.2    59.6  0.7888

# %%
#Creo una función que me retorne si para los valores mayores a 1000 en "oxInd"
def newVal(x):
    if x>1000:
        return 'Yes'
    else :
        return 'No'

# %%
aire['oxInd'].apply(lambda x: newVal(x))
# Out:
# dt
# 2004-03-10 18:00:00    Yes
# 2004-03-10 19:00:00     No
# 2004-03-10 20:00:00    Yes
# 2004-03-10 21:00:00    Yes
# 2004-03-10 22:00:00    Yes
#                       ...
# 2005-04-04 10:00:00    Yes
# 2005-04-04 11:00:00    Yes
# 2005-04-04 12:00:00    Yes
# 2005-04-04 13:00:00     No
# 2005-04-04 14:00:00     No
# Name: oxInd, Length: 9357, dtype: object
